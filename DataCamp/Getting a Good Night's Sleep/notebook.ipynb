# %% [markdown]
# ![insomnia](insomnia.jpg)

# %% [markdown]
# Your client, SleepInc, has shared anonymized sleep data from their hot new sleep tracking app SleepScope. As their data science consultant, your mission is to analyze the lifestyle survey data with Python to discover relationships between exercise, gender, occupation, and sleep quality. See if you can identify patterns leading to insights on sleep quality.
#
# ## 💾 The data: sleep_health_data.csv
#
# SleepInc has provided you with an anonymized dataset of sleep and lifestyle metrics for 374 individuals. This dataset contains average values for each person calculated over the past six months. The data is saved as `sleep_health_data.csv`.
#
# The dataset includes 13 columns covering sleep duration, quality, disorders, exercise, stress, diet, demographics, and other factors related to sleep health.
#
# | Column | Description |
# |---------|----------------------------------------|
# | `Person ID` | An identifier for each individual. |
# | `Gender` | The gender of the person (Male/Female). |
# | `Age` | The age of the person in years. |
# | `Occupation` | The occupation or profession of the person. |
# | `Sleep Duration (hours)` | The average number of hours the person sleeps per day. |
# | `Quality of Sleep (scale: 1-10)` | A subjective rating of the quality of sleep, ranging from 1 to 10. |
# | `Physical Activity Level (minutes/day)` | The average number of minutes the person engages in physical activity daily. |
# | `Stress Level (scale: 1-10)` | A subjective rating of the stress level experienced by the person, ranging from 1 to 10. |
# | `BMI Category` | The BMI category of the person (e.g., Underweight, Normal, Overweight). |
# | `Blood Pressure (systolic/diastolic)` | The average blood pressure measurement of the person, indicated as systolic pressure over diastolic pressure. |
# | `Heart Rate (bpm)` | The average resting heart rate of the person in beats per minute. |
# | `Daily Steps` | The average number of steps the person takes per day. |
# | `Sleep Disorder` | The presence or absence of a sleep disorder in the person (None, Insomnia, Sleep Apnea). |

# %%
# Start coding here
# Use as many cells as you need
import pandas as pd

# Read the dataset
sleep_df = pd.read_csv('sleep_health_data.csv')

# %%
# Calculate the average sleep duration for each occupation
sleep_occ = sleep_df.groupby('Occupation')['Sleep Duration'].mean()
sleep_occ
# Out:
# Occupation
# Accountant              7.113514
# Doctor                  6.970423
# Engineer                7.987302
# Lawyer                  7.410638
# Manager                 6.900000
# Nurse                   7.063014
# Sales Representative    5.900000
# Salesperson             6.403125
# Scientist               6.000000
# Software Engineer       6.750000
# Teacher                 6.690000
# Name: Sleep Duration, dtype: float64

# %%
# Get the occupation with the lowest average sleep duration
lowest_sleep_occ = sleep_occ.sort_values().index[0]
print('The occupation with the lowest average sleep duration is ' + lowest_sleep_occ)
# Out:
# The occupation with the lowest average sleep duration is Sales Representative

# %%
# Calculate the average sleep quality for each occupation
sleep_quality_occ = sleep_df.groupby('Occupation')['Quality of Sleep'].mean()
sleep_quality_occ
# Out:
# Occupation
# Accountant              7.891892
# Doctor                  6.647887
# Engineer                8.412698
# Lawyer                  7.893617
# Manager                 7.000000
# Nurse                   7.369863
# Sales Representative    4.000000
# Salesperson             6.000000
# Scientist               5.000000
# Software Engineer       6.500000
# Teacher                 6.975000
# Name: Quality of Sleep, dtype: float64

# %%
# Get the occupation with the lowest average sleep quality
lowest_sleep_quality_occ = sleep_quality_occ.sort_values().index[0]
print('The occupation with the lowest average sleep quality is ' + lowest_sleep_quality_occ)
# Out:
# The occupation with the lowest average sleep quality is Sales Representative

# %%
# Set a boolean variable to see if the occupation with the
# lowest sleep duration also have the lowest sleep quality
if lowest_sleep_occ == lowest_sleep_quality_occ:
    same_occ = True
else:
    same_occ = False
same_occ
# Out:
# True

# %%
# Get the BMI Category and Sleep Disorder data based on
# users with Insomnia
normal = sleep_df[(sleep_df["BMI Category"] == "Normal") & (sleep_df["Sleep Disorder"] == "Insomnia")]
overweight = sleep_df[(sleep_df["BMI Category"] == "Overweight") & (sleep_df["Sleep Disorder"] == "Insomnia")]
obese = sleep_df[(sleep_df["BMI Category"] == "Obese") &  (sleep_df["Sleep Disorder"] == "Insomnia")]
print(normal.head())
print(overweight.head())
print(obese.head())
# Out:
#      Person ID  Gender  Age  ... Heart Rate  Daily Steps  Sleep Disorder
# 18          19  Female   29  ...         80         4000        Insomnia
# 31          32  Female   30  ...         78         4100        Insomnia
# 67          68    Male   33  ...         72         5000        Insomnia
# 94          95  Female   36  ...         68         7000        Insomnia
# 146        147    Male   39  ...         68         8000        Insomnia
#
# [5 rows x 13 columns]
#      Person ID  Gender  Age  ... Heart Rate  Daily Steps  Sleep Disorder
# 105        106    Male   36  ...         74         4800        Insomnia
# 147        148    Male   39  ...         80         4000        Insomnia
# 177        178    Male   42  ...         72         6000        Insomnia
# 186        187  Female   43  ...         65         6000        Insomnia
# 187        188    Male   43  ...         72         6000        Insomnia
#
# [5 rows x 13 columns]
#      Person ID Gender  Age  ... Heart Rate  Daily Steps  Sleep Disorder
# 5            6   Male   28  ...         85         3000        Insomnia
# 6            7   Male   29  ...         82         3500        Insomnia
# 264        265   Male   48  ...         83         3500        Insomnia
# 266        267   Male   48  ...         83         3500        Insomnia
#
# [4 rows x 13 columns]

# %%
# Find a ratio of app users in each BMI category that have
# been diagnosed with Insomnia
total_normal = len(sleep_df[sleep_df['BMI Category'] == 'Normal'])
normal_insomnia_ratio = round(len(normal) / total_normal, 2) 

total_overweight = len(sleep_df[sleep_df['BMI Category'] == 'Overweight'])
overweight_insomnia_ratio = round(len(overweight) / total_overweight, 2)

total_obese = len(sleep_df[sleep_df['BMI Category'] == 'Obese'])
obese_insomnia_ratio = round(len(obese) / total_obese, 2)

# Create a dictionary
bmi_insomnia_ratios = {
    "Normal": normal_insomnia_ratio,
    "Overweight": overweight_insomnia_ratio,
    "Obese": obese_insomnia_ratio
}

bmi_insomnia_ratios
# Out:
# {'Normal': 0.04, 'Overweight': 0.43, 'Obese': 0.4}
